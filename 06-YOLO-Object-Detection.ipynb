# %% [markdown]
# # YOLO v3 Object Detection
#
# Let's see how to use the state of the art in object detection! Please make sure to watch the video, there is no code along here, since we can't reasonably train the YOLOv3 network ourself, instead we will use a pre-established version.
#
# CODE SOURCE: https://github.com/xiaochus/YOLOv3
#
# REFERENCE (for original YOLOv3):
#
#         @article{YOLOv3,
#               title={YOLOv3: An Incremental Improvement},
#               author={J Redmon, A Farhadi },
#               year={2018}
# --------
# ----------
# ## YOU MUST WATCH THE VIDEO LECTURE TO PROPERLY SET UP THE MODEL AND WEIGHTS. THIS NOTEBOOK WON'T WORK UNLESS YOU FOLLOW THE EXACT SET UP SHOWN IN THE VIDEO LECTURE.
# -------
# -------

# %%
import tensorflow

# %%
import os
import time
import cv2
import numpy as np
from model.yolo_model import YOLO

# %%
def process_image(img):
    """Resize, reduce and expand image.

    # Argument:
        img: original image.

    # Returns
        image: ndarray(64, 64, 3), processed image.
    """
    image = cv2.resize(img, (416, 416),
                       interpolation=cv2.INTER_CUBIC)
    image = np.array(image, dtype='float32')
    image /= 255.
    image = np.expand_dims(image, axis=0)

    return image

# %%
def get_classes(file):
    """Get classes name.

    # Argument:
        file: classes name for database.

    # Returns
        class_names: List, classes name.

    """
    with open(file) as f:
        class_names = f.readlines()
    class_names = [c.strip() for c in class_names]

    return class_names

# %%
def draw(image, boxes, scores, classes, all_classes):
    """Draw the boxes on the image.

    # Argument:
        image: original image.
        boxes: ndarray, boxes of objects.
        classes: ndarray, classes of objects.
        scores: ndarray, scores of objects.
        all_classes: all classes name.
    """
    for box, score, cl in zip(boxes, scores, classes):
        x, y, w, h = box

        top = max(0, np.floor(x + 0.5).astype(int))
        left = max(0, np.floor(y + 0.5).astype(int))
        right = min(image.shape[1], np.floor(x + w + 0.5).astype(int))
        bottom = min(image.shape[0], np.floor(y + h + 0.5).astype(int))

        cv2.rectangle(image, (top, left), (right, bottom), (255, 0, 0), 2)
        cv2.putText(image, '{0} {1:.2f}'.format(all_classes[cl], score),
                    (top, left - 6),
                    cv2.FONT_HERSHEY_SIMPLEX,
                    0.6, (0, 0, 255), 1,
                    cv2.LINE_AA)

        print('class: {0}, score: {1:.2f}'.format(all_classes[cl], score))
        print('box coordinate x,y,w,h: {0}'.format(box))

    print()

# %%
def detect_image(image, yolo, all_classes):
    """Use yolo v3 to detect images.

    # Argument:
        image: original image.
        yolo: YOLO, yolo model.
        all_classes: all classes name.

    # Returns:
        image: processed image.
    """
    pimage = process_image(image)

    start = time.time()
    boxes, classes, scores = yolo.predict(pimage, image.shape)
    end = time.time()

    print('time: {0:.2f}s'.format(end - start))

    if boxes is not None:
        draw(image, boxes, scores, classes, all_classes)

    return image

# %%
def detect_video(video, yolo, all_classes):
    """Use yolo v3 to detect video.

    # Argument:
        video: video file.
        yolo: YOLO, yolo model.
        all_classes: all classes name.
    """
    video_path = os.path.join("videos", "test", video)
    camera = cv2.VideoCapture(video_path)
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)

    # Prepare for saving the detected video
    sz = (int(camera.get(cv2.CAP_PROP_FRAME_WIDTH)),
        int(camera.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    fourcc = cv2.VideoWriter_fourcc(*'mpeg')

    
    vout = cv2.VideoWriter()
    vout.open(os.path.join("videos", "res", video), fourcc, 20, sz, True)

    while True:
        res, frame = camera.read()

        if not res:
            break

        image = detect_image(frame, yolo, all_classes)
        cv2.imshow("detection", image)

        # Save the video frame by frame
        vout.write(image)

        if cv2.waitKey(110) & 0xff == 27:
                break

    vout.release()
    camera.release()

# %%
yolo = YOLO(0.6, 0.5)
file = 'data/coco_classes.txt'
# all_classes = get_classes(file)
# Out:
# WARNING:tensorflow:No training configuration found in the save file, so the model was *not* compiled. Compile it manually.

# %% [markdown]
# ### Detecting Images

# %%
print(image)
process_image(image)
# Out:
# None
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-23-e529a1935ffc> in <module>
#       1 print(image)
# ----> 2 process_image(image)
#
# <ipython-input-21-60ea229bada9> in process_image(img)
#       9     """
#      10 #     print(img.shape)
# ---> 11     image = cv2.resize(img,(224,224),fx=0,fy=0, interpolation = cv2.INTER_CUBIC)
#      12     image = np.array(image, dtype='float32')
#      13     image /= 255.
#
# error: OpenCV(4.6.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4052: error: (-215:Assertion failed) !ssize.empty() in function 'cv::resize'

# %%
f = 'formals.jpeg'
path = 'images/'+f
image = cv2.imread(path)
image = detect_image(image, yolo, all_classes)
cv2.imwrite('images/res/' + f, image)
# Out:
# 1/1 [==============================] - 2s 2s/step
# time: 1.71s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 97.60655165  73.66957426 561.11924171 952.34444618]
# class: tie, score: 0.95
# box coordinate x,y,w,h: [390.5273366  372.70505548 117.67774433 476.9596982 ]
# True

# %% [markdown]
# # Detecting on Video

# %%
# detect videos one at a time in videos/test folder    
video = 'college.mp4'
path='videos/'+video
detect_video(video, yolo, all_classes)
# Out:
# 1/1 [==============================] - 0s 433ms/step
# time: 0.49s
# 1/1 [==============================] - 0s 439ms/step
# time: 0.51s
# 1/1 [==============================] - 0s 434ms/step
# time: 0.52s
# 1/1 [==============================] - 0s 437ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 420ms/step
# time: 0.49s
# 1/1 [==============================] - 0s 429ms/step
# time: 0.52s
# 1/1 [==============================] - 0s 419ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 419ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 424ms/step
# time: 0.48s
# 1/1 [==============================] - 0s 421ms/step
# time: 0.48s
# 1/1 [==============================] - 0s 433ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 421ms/step
# time: 0.49s
# 1/1 [==============================] - 0s 430ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 430ms/step
# time: 0.51s
# 1/1 [==============================] - 0s 420ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 424ms/step
# time: 0.52s
# 1/1 [==============================] - 0s 473ms/step
# time: 0.55s
# 1/1 [==============================] - 0s 428ms/step
# time: 0.51s
# 1/1 [==============================] - 0s 435ms/step
# time: 0.52s
# 1/1 [==============================] - 1s 500ms/step
# time: 0.57s
# 1/1 [==============================] - 0s 432ms/step
# time: 0.52s
# 1/1 [==============================] - 0s 436ms/step
# time: 0.53s
# 1/1 [==============================] - 0s 461ms/step
# time: 0.54s
# 1/1 [==============================] - 0s 423ms/step
# time: 0.50s
# 1/1 [==============================] - 1s 556ms/step
# time: 0.64s
# 1/1 [==============================] - 0s 450ms/step
# time: 0.53s
# 1/1 [==============================] - 0s 438ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 430ms/step
# time: 0.50s
# 1/1 [==============================] - 0s 433ms/step
# time: 0.51s
# 1/1 [==============================] - 0s 424ms/step
# time: 0.51s
# 1/1 [==============================] - 0s 447ms/step
# time: 0.52s
# 1/1 [==============================] - 0s 453ms/step
# time: 0.52s
# 1/1 [==============================] - 0s 422ms/step
# time: 0.49s
# 1/1 [==============================] - 0s 441ms/step
# time: 0.54s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-b81c6119cc8f> in <module>
#       2 video = 'college.mp4'
#       3 path='videos/'+video
# ----> 4 detect_video(video, yolo, all_classes)
#
# <ipython-input-6-77aec999d517> in detect_video(video, yolo, all_classes)
#      21
#      22     while True:
# ---> 23         res, frame = camera.read()
#      24
#      25         if not res:
#
# KeyboardInterrupt:

# %%
def frontcam( yolo, all_classes):
    camera = cv2.VideoCapture(1)
    cv2.namedWindow("detection", cv2.WINDOW_AUTOSIZE)

    # sz = (int(camera.get(cv2.CAP_PROP_FRAME_WIDTH)),
    #     int(camera.get(cv2.CAP_PROP_FRAME_HEIGHT)))
    # fourcc = cv2.VideoWriter_fourcc(*'mpeg')
    # 
    # 
    # vout = cv2.VideoWriter()
    # vout.open(os.path.join("videos", "res", video), fourcc, 20, sz, True)

    while True:
        res, frame = camera.read()
        if not res:
            break
        image = detect_image(frame, yolo, all_classes)
        cv2.imshow("detection", image)

        # Save the video frame by frame
        # vout.write(image)

        if cv2.waitKey(110) & 0xff == 27:
                break

    # vout.release()
    camera.release()

# %%
frontcam(yolo,all_classes)
# Out:
# 1/1 [==============================] - 2s 2s/step
# time: 2.58s
# 1/1 [==============================] - 1s 574ms/step
# time: 0.66s
# class: person, score: 0.86
# box coordinate x,y,w,h: [ 18.63950729  12.53445625 617.2220993  466.78905487]
#
# 1/1 [==============================] - 1s 567ms/step
# time: 0.65s
# class: person, score: 0.76
# box coordinate x,y,w,h: [ 11.32688522  31.45726204 623.41594696 430.32714844]
#
# 1/1 [==============================] - 1s 564ms/step
# time: 0.64s
# class: person, score: 0.91
# box coordinate x,y,w,h: [ 16.12371445  21.23063564 621.53560638 440.96240044]
#
# 1/1 [==============================] - 1s 569ms/step
# time: 0.66s
# 1/1 [==============================] - 1s 571ms/step
# time: 0.67s
# 1/1 [==============================] - 1s 583ms/step
# time: 0.66s
# class: person, score: 0.80
# box coordinate x,y,w,h: [2.91617203e+01 4.57534790e-01 5.75727615e+02 4.80981674e+02]
#
# 1/1 [==============================] - 1s 598ms/step
# time: 0.69s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 78.81141663  85.38249493 499.64576721 377.46920586]
#
# 1/1 [==============================] - 1s 569ms/step
# time: 0.66s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 62.99034119 203.61835957 518.10348511 272.33422279]
#
# 1/1 [==============================] - 1s 570ms/step
# time: 0.66s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 55.32852173 137.2679615  543.43070984 348.27260971]
#
# 1/1 [==============================] - 1s 584ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 56.59015656  22.94091225 546.25183105 433.00186157]
#
# 1/1 [==============================] - 1s 575ms/step
# time: 0.68s
# class: person, score: 0.94
# box coordinate x,y,w,h: [ 53.48176956   5.80234051 550.31597137 386.89619064]
#
# 1/1 [==============================] - 1s 569ms/step
# time: 0.65s
# class: person, score: 0.96
# box coordinate x,y,w,h: [ 62.94487     16.11412525 539.18945312 372.71115303]
#
# 1/1 [==============================] - 1s 577ms/step
# time: 0.66s
# class: person, score: 0.99
# box coordinate x,y,w,h: [151.54727936   5.9992075  414.30297852 387.60197639]
#
# 1/1 [==============================] - 1s 564ms/step
# time: 0.66s
# class: person, score: 0.94
# box coordinate x,y,w,h: [212.03802109  61.04511738 391.50470734 335.53470612]
#
# 1/1 [==============================] - 1s 582ms/step
# time: 0.66s
# class: person, score: 0.98
# box coordinate x,y,w,h: [212.16255188  61.9580555  386.70883179 337.69526482]
#
# 1/1 [==============================] - 1s 581ms/step
# time: 0.66s
# class: person, score: 0.99
# box coordinate x,y,w,h: [184.13600922  34.02887821 371.55906677 355.50573349]
#
# 1/1 [==============================] - 1s 595ms/step
# time: 0.67s
# class: person, score: 0.99
# box coordinate x,y,w,h: [121.34153366  44.87052441 425.07320404 342.63356209]
#
# 1/1 [==============================] - 1s 591ms/step
# time: 0.67s
# class: person, score: 0.98
# box coordinate x,y,w,h: [144.34770584  34.20610428 436.22249603 360.76598167]
#
# 1/1 [==============================] - 1s 578ms/step
# time: 0.65s
# class: person, score: 0.98
# box coordinate x,y,w,h: [145.42848587  42.78244972 427.54558563 375.98828316]
#
# 1/1 [==============================] - 1s 593ms/step
# time: 0.70s
# class: person, score: 0.99
# box coordinate x,y,w,h: [150.01888275  48.75759602 419.22538757 360.84222794]
#
# 1/1 [==============================] - 1s 595ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [148.5502243   42.92409897 427.397995   345.51149368]
#
# 1/1 [==============================] - 1s 580ms/step
# time: 0.67s
# class: person, score: 0.90
# box coordinate x,y,w,h: [ 82.24637985  33.85437012 482.54367828 360.04603386]
# class: toothbrush, score: 0.73
# box coordinate x,y,w,h: [ 27.86735535  66.99829102 394.13383484  68.27059507]
#
# 1/1 [==============================] - 1s 618ms/step
# time: 0.72s
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 70.22151947  48.97210121 501.67198181 360.69886208]
# class: toothbrush, score: 0.71
# box coordinate x,y,w,h: [ 54.01596069 155.5822134  360.22315979  47.16287255]
#
# 1/1 [==============================] - 1s 580ms/step
# time: 0.67s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 66.88747406  53.08543682 509.47013855 351.62103653]
# class: toothbrush, score: 0.96
# box coordinate x,y,w,h: [ 38.08988571 147.82343388 371.78413391  49.39447761]
#
# 1/1 [==============================] - 1s 579ms/step
# time: 0.67s
# 1/1 [==============================] - 1s 591ms/step
# time: 0.67s
# class: person, score: 0.99
# box coordinate x,y,w,h: [109.24451828  41.76203728 446.27521515 346.40710831]
#
# 1/1 [==============================] - 1s 607ms/step
# time: 0.69s
# class: person, score: 0.99
# box coordinate x,y,w,h: [108.19818497  51.22449875 449.2975235  330.51395416]
#
# 1/1 [==============================] - 1s 591ms/step
# time: 0.67s
# class: person, score: 0.99
# box coordinate x,y,w,h: [131.54230118  43.49766254 448.82587433 344.14469719]
#
# 1/1 [==============================] - 1s 597ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [161.10342026  48.01869392 431.82598114 337.48429298]
#
# 1/1 [==============================] - 1s 604ms/step
# time: 0.68s
# class: person, score: 0.97
# box coordinate x,y,w,h: [167.82844543  49.6763134  393.3391571  359.01806831]
#
# 1/1 [==============================] - 1s 584ms/step
# time: 0.67s
# class: person, score: 0.98
# box coordinate x,y,w,h: [179.61595535  52.62818813 380.09021759 357.60881424]
#
# 1/1 [==============================] - 1s 588ms/step
# time: 0.67s
# class: person, score: 0.98
# box coordinate x,y,w,h: [179.70788956  30.50597191 375.20381927 360.08563042]
#
# 1/1 [==============================] - 1s 584ms/step
# time: 0.66s
# class: person, score: 0.99
# box coordinate x,y,w,h: [169.16362762  26.84038639 391.53427124 363.22966576]
#
# 1/1 [==============================] - 1s 588ms/step
# time: 0.66s
# class: person, score: 0.99
# box coordinate x,y,w,h: [167.05518723  26.18170738 389.7662735  364.34984207]
#
# 1/1 [==============================] - 1s 576ms/step
# time: 0.66s
# class: person, score: 0.92
# box coordinate x,y,w,h: [179.85370636  26.38967514 378.2459259  373.93372536]
#
# 1/1 [==============================] - 1s 593ms/step
# time: 0.67s
# class: person, score: 0.92
# box coordinate x,y,w,h: [184.33023453  28.09136868 363.66970062 372.47148514]
#
# 1/1 [==============================] - 1s 586ms/step
# time: 0.67s
# 1/1 [==============================] - 1s 590ms/step
# time: 0.67s
# 1/1 [==============================] - 1s 604ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [165.73526382  38.3088541  412.21279144 354.45087433]
#
# 1/1 [==============================] - 1s 585ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [170.09145737  34.16607857 415.31536102 355.51523209]
#
# 1/1 [==============================] - 1s 592ms/step
# time: 0.69s
# class: person, score: 1.00
# box coordinate x,y,w,h: [153.84634018  27.35090733 431.11728668 356.85424805]
#
# 1/1 [==============================] - 1s 587ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [149.57876205  15.647192   453.04508209 373.36094856]
#
# 1/1 [==============================] - 1s 590ms/step
# time: 0.69s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 62.24960327  14.30492878 520.38772583 383.16255569]
#
# 1/1 [==============================] - 1s 591ms/step
# time: 0.69s
# class: person, score: 0.92
# box coordinate x,y,w,h: [107.10540771  17.22587585 439.88838196 390.50416946]
#
# 1/1 [==============================] - 1s 604ms/step
# time: 0.69s
# class: person, score: 0.99
# box coordinate x,y,w,h: [118.91841888  18.60453129 329.82681274 380.74361801]
#
# 1/1 [==============================] - 1s 609ms/step
# time: 0.69s
# class: person, score: 0.99
# box coordinate x,y,w,h: [140.07442474  26.65195942 356.19297028 359.78473663]
# class: toothbrush, score: 0.68
# box coordinate x,y,w,h: [135.56015968  44.29002285 287.16173172 314.60938454]
#
# 1/1 [==============================] - 1s 591ms/step
# time: 0.67s
# class: person, score: 0.99
# box coordinate x,y,w,h: [139.39189911  26.12349987 355.56171417 361.29278183]
#
# 1/1 [==============================] - 1s 578ms/step
# time: 0.65s
# class: person, score: 0.99
# box coordinate x,y,w,h: [135.99054337  25.69792271 357.66689301 362.5496006 ]
#
# 1/1 [==============================] - 1s 614ms/step
# time: 0.70s
# class: person, score: 0.99
# box coordinate x,y,w,h: [151.80530548  32.1476841  326.42757416 355.44528008]
#
# 1/1 [==============================] - 1s 601ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [130.30590057  24.42153454 373.40133667 365.39411545]
#
# 1/1 [==============================] - 1s 599ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [131.95249557  23.32755089 373.68312836 370.33178329]
#
# 1/1 [==============================] - 1s 582ms/step
# time: 0.66s
# class: person, score: 1.00
# box coordinate x,y,w,h: [130.19073486  24.54061031 378.36898804 371.67818069]
#
# 1/1 [==============================] - 1s 575ms/step
# time: 0.66s
# class: person, score: 1.00
# box coordinate x,y,w,h: [133.23404312  20.74808121 371.76509857 373.49710464]
#
# 1/1 [==============================] - 1s 589ms/step
# time: 0.67s
# class: person, score: 0.98
# box coordinate x,y,w,h: [103.76699448  15.36605358 429.04239655 386.11956596]
#
# 1/1 [==============================] - 1s 586ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 90.45272827  29.47772026 454.32174683 359.96435165]
#
# 1/1 [==============================] - 1s 596ms/step
# time: 0.69s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 92.19600677  31.38513565 457.80479431 358.82094383]
#
# 1/1 [==============================] - 1s 587ms/step
# time: 0.66s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 99.84077454  22.97460079 440.8744812  361.92770004]
#
# 1/1 [==============================] - 1s 587ms/step
# time: 0.66s
# class: person, score: 0.99
# box coordinate x,y,w,h: [141.02519989  22.90138721 353.77574921 367.3095417 ]
#
# 1/1 [==============================] - 1s 609ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [137.62742996  21.02295399 362.26829529 371.97232246]
#
# 1/1 [==============================] - 1s 580ms/step
# time: 0.66s
# class: person, score: 1.00
# box coordinate x,y,w,h: [139.70727921  17.19456196 368.41625214 378.21344376]
#
# 1/1 [==============================] - 1s 586ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [113.38779449  27.77089119 411.25671387 368.07117462]
#
# 1/1 [==============================] - 1s 583ms/step
# time: 0.67s
# class: person, score: 0.99
# box coordinate x,y,w,h: [119.03898239  23.07899952 404.14142609 377.65256882]
#
# 1/1 [==============================] - 1s 595ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [111.29497528  32.5370121  419.08439636 365.25255203]
#
# 1/1 [==============================] - 1s 599ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [118.81757736  34.19197083 406.00406647 357.90018082]
#
# 1/1 [==============================] - 1s 592ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [110.04508972  29.59885597 421.89964294 366.02537155]
#
# 1/1 [==============================] - 1s 594ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [117.52912521  26.38994694 405.68202972 375.89421272]
#
# 1/1 [==============================] - 1s 572ms/step
# time: 0.66s
# class: person, score: 1.00
# box coordinate x,y,w,h: [107.25727081  23.29157352 402.5856781  374.44825172]
#
# 1/1 [==============================] - 1s 595ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [118.29624176   6.08084679 494.96192932 391.222229  ]
#
# 1/1 [==============================] - 1s 593ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [110.9863472   19.6642828  514.66312408 367.81050682]
#
# 1/1 [==============================] - 1s 594ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [108.03312302  47.5339365  435.11959076 325.45045853]
#
# 1/1 [==============================] - 1s 598ms/step
# time: 0.70s
# class: person, score: 1.00
# box coordinate x,y,w,h: [101.53001785  49.70067501 443.53786469 321.71021461]
# class: cell phone, score: 0.67
# box coordinate x,y,w,h: [358.23532104 128.98263931  84.31116104 136.28859043]
#
# 1/1 [==============================] - 1s 596ms/step
# time: 0.69s
# class: person, score: 1.00
# box coordinate x,y,w,h: [106.65218353  49.63890553 428.42063904 322.43213654]
#
# 1/1 [==============================] - 1s 608ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [104.49474335  48.34705353 437.66654968 317.20796585]
#
# 1/1 [==============================] - 1s 601ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [123.06165695  23.06292057 503.14540863 362.77044296]
#
# 1/1 [==============================] - 1s 602ms/step
# time: 0.69s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 90.38785934   3.53087425 477.95566559 400.94633102]
# class: tie, score: 0.65
# box coordinate x,y,w,h: [279.15367126 136.24221325 159.73630905  85.98953962]
#
# 1/1 [==============================] - 1s 608ms/step
# time: 0.69s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 85.20593643   1.41095638 548.00922394 398.84173393]
#
# 1/1 [==============================] - 1s 583ms/step
# time: 0.67s
# 1/1 [==============================] - 1s 599ms/step
# time: 0.68s
# class: person, score: 0.97
# box coordinate x,y,w,h: [ 88.46464157   8.30796719 552.58945465 396.13417625]
#
# 1/1 [==============================] - 1s 605ms/step
# time: 0.69s
# class: person, score: 0.92
# box coordinate x,y,w,h: [113.13144684  -2.17356205 426.92001343 412.82761574]
#
# 1/1 [==============================] - 1s 588ms/step
# time: 0.67s
# class: person, score: 0.92
# box coordinate x,y,w,h: [107.42271423  49.91982937 430.79086304 361.3766098 ]
#
# 1/1 [==============================] - 1s 601ms/step
# time: 0.69s
# class: person, score: 0.85
# box coordinate x,y,w,h: [ 99.72005844  28.99828434 355.85441589 363.6893177 ]
#
# 1/1 [==============================] - 1s 591ms/step
# time: 0.67s
# class: person, score: 0.82
# box coordinate x,y,w,h: [ 92.98837662  27.20213413 365.25981903 366.78191185]
#
# 1/1 [==============================] - 1s 589ms/step
# time: 0.69s
# class: person, score: 0.96
# box coordinate x,y,w,h: [115.7734108   25.34975052 406.01707458 376.28173828]
#
# 1/1 [==============================] - 1s 597ms/step
# time: 0.71s
# class: person, score: 0.98
# box coordinate x,y,w,h: [105.266819    48.29426765 438.80153656 364.19603348]
#
# 1/1 [==============================] - 1s 601ms/step
# time: 0.68s
# class: bottle, score: 0.70
# box coordinate x,y,w,h: [237.4275589   27.88478851 139.85757828 356.00538254]
#
# 1/1 [==============================] - 1s 603ms/step
# time: 0.68s
# class: bottle, score: 0.65
# box coordinate x,y,w,h: [210.47534943  25.66522121 192.30571747 369.19816017]
#
# 1/1 [==============================] - 1s 597ms/step
# time: 0.67s
# class: person, score: 0.77
# box coordinate x,y,w,h: [109.81365204  36.72263145 439.70527649 393.99084091]
#
# 1/1 [==============================] - 1s 606ms/step
# time: 0.68s
# class: person, score: 0.80
# box coordinate x,y,w,h: [157.55146027  25.78396797 411.97395325 364.91884232]
#
# 1/1 [==============================] - 1s 602ms/step
# time: 0.69s
# 1/1 [==============================] - 1s 618ms/step
# time: 0.71s
# 1/1 [==============================] - 1s 605ms/step
# time: 0.67s
# 1/1 [==============================] - 1s 591ms/step
# time: 0.67s
# 1/1 [==============================] - 1s 610ms/step
# time: 0.69s
# 1/1 [==============================] - 1s 597ms/step
# time: 0.68s
# class: vase, score: 0.85
# box coordinate x,y,w,h: [199.56558228  19.62631702 233.15286636 371.70084   ]
#
# 1/1 [==============================] - 1s 612ms/step
# time: 0.69s
# 1/1 [==============================] - 1s 614ms/step
# time: 0.69s
# class: person, score: 0.95
# box coordinate x,y,w,h: [122.05316544  29.71278191 414.65373993 364.02042389]
#
# 1/1 [==============================] - 1s 614ms/step
# time: 0.70s
# class: person, score: 0.99
# box coordinate x,y,w,h: [114.50832367  35.9787941  422.19604492 354.7755146 ]
#
# 1/1 [==============================] - 1s 618ms/step
# time: 0.71s
# class: person, score: 0.99
# box coordinate x,y,w,h: [116.02487564  30.97376347 422.51140594 358.55621338]
# class: bottle, score: 0.79
# box coordinate x,y,w,h: [306.80528641 178.4491539   89.1605854  214.46006298]
#
# 1/1 [==============================] - 1s 586ms/step
# time: 0.67s
# class: person, score: 0.99
# box coordinate x,y,w,h: [125.29291153  35.22703171 402.19867706 346.99859619]
# 1/1 [==============================] - 1s 603ms/step
# time: 0.69s
# class: person, score: 0.91
# box coordinate x,y,w,h: [122.26465225  28.02685261 414.46109772 361.59427643]
#
# 1/1 [==============================] - 1s 645ms/step
# time: 0.73s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 44.19525146  30.15562534 534.27005768 359.68008041]
#
# 1/1 [==============================] - 1s 591ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 43.17163467   6.17026806 522.29640961 405.63735008]
#
# 1/1 [==============================] - 1s 585ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 39.5158577   12.18315125 531.47163391 392.87916183]
#
# 1/1 [==============================] - 1s 577ms/step
# time: 0.66s
# class: person, score: 1.00
# box coordinate x,y,w,h: [164.49100494   4.50309277 438.84162903 386.04457855]
#
# 1/1 [==============================] - 1s 642ms/step
# time: 0.72s
# class: person, score: 1.00
# box coordinate x,y,w,h: [179.56176758   3.38434696 446.03096008 391.13505363]
#
# 1/1 [==============================] - 1s 598ms/step
# time: 0.68s
# class: person, score: 1.00
# box coordinate x,y,w,h: [182.03121185  10.79558372 448.51074219 376.80378914]
#
# 1/1 [==============================] - 1s 593ms/step
# time: 0.69s
# class: person, score: 0.87
# box coordinate x,y,w,h: [173.49121094   9.27756786 460.09902954 393.17061424]
#
# 1/1 [==============================] - 1s 604ms/step
# time: 0.69s
# 1/1 [==============================] - 1s 596ms/step
# time: 0.67s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 74.20082092   7.74257183 500.23674011 379.41939354]
#
# 1/1 [==============================] - 1s 600ms/step
# time: 0.68s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 62.24132538  11.88643456 536.44523621 381.8771553 ]
#
# 1/1 [==============================] - 1s 606ms/step
# time: 0.71s
# class: person, score: 0.99
# box coordinate x,y,w,h: [ 66.85634613  11.96605682 529.00428772 383.08210373]
#
# 1/1 [==============================] - 1s 596ms/step
# time: 0.68s
# class: person, score: 0.98
# box coordinate x,y,w,h: [ 62.35374451  15.15701294 537.83668518 375.84222794]
#
# 1/1 [==============================] - 1s 645ms/step
# time: 0.93s
# class: person, score: 0.99
# box coordinate x,y,w,h: [112.13779449   9.05872822 493.96080017 383.20034981]
#
# 1/1 [==============================] - 1s 652ms/step
# time: 0.77s
# class: person, score: 1.00
# box coordinate x,y,w,h: [115.07972717  14.91881847 487.07496643 378.79119873]
#
# 1/1 [==============================] - 1s 626ms/step
# time: 0.74s
# class: person, score: 1.00
# box coordinate x,y,w,h: [106.28189087  34.13659573 452.13134766 340.84685326]
#
# 1/1 [==============================] - 1s 639ms/step
# time: 0.76s
# class: person, score: 1.00
# box coordinate x,y,w,h: [147.95564651  34.6385479  425.27141571 341.65294647]
#
# 1/1 [==============================] - 1s 618ms/step
# time: 0.75s
# class: person, score: 1.00
# box coordinate x,y,w,h: [150.35579681  32.74387836 424.05258179 348.52372169]
#
# 1/1 [==============================] - 1s 624ms/step
# time: 0.75s
# class: person, score: 1.00
# box coordinate x,y,w,h: [136.66648865  32.65625954 446.93992615 344.85566139]
#
# 1/1 [==============================] - 1s 621ms/step
# time: 0.74s
# class: person, score: 1.00
# box coordinate x,y,w,h: [103.30152512  32.22576141 465.42377472 348.48695755]
#
# 1/1 [==============================] - 1s 630ms/step
# time: 0.72s
# class: person, score: 1.00
# box coordinate x,y,w,h: [101.14818573  31.48780346 467.41783142 350.87236404]
#
# 1/1 [==============================] - 1s 616ms/step
# time: 0.73s
# class: person, score: 1.00
# box coordinate x,y,w,h: [101.10385895  28.38795662 464.12826538 356.41971588]
#
# 1/1 [==============================] - 1s 665ms/step
# time: 0.81s
# class: person, score: 1.00
# box coordinate x,y,w,h: [ 48.85639191  10.98102093 545.23742676 398.44754219]
#
# 1/1 [==============================] - 1s 619ms/step
# time: 0.73s
# 1/1 [==============================] - 1s 632ms/step
# time: 0.72s
# class: person, score: 0.61
# box coordinate x,y,w,h: [ 36.69589996  26.5140152  557.75505066 405.37027359]

# %%
tensorflow.keras.utils.plot_model(yolo)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-e9e42ec14329> in <module>
# ----> 1 tensorflow.keras.utils.plot_model(yolo)
#
# ~\anaconda3\lib\site-packages\keras\utils\vis_utils.py in plot_model(model, to_file, show_shapes, show_dtype, show_layer_names, rankdir, expand_nested, dpi, layer_range, show_layer_activations)
#     427     """
#     428
# --> 429     if not model.built:
#     430         raise ValueError(
#     431             "This model has not yet been built. "
#
# AttributeError: 'YOLO' object has no attribute 'built'
